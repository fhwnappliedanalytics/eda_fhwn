# %% [markdown]
# ## Sweetviz
# Sweetviz is an open-source Python library that generates beautiful, high-density visualizations to kickstart EDA (Exploratory Data Analysis) with just two lines of code. Output is a fully self-contained HTML application.
#
# The system is built around quickly visualizing target values and comparing datasets. Its goal is to help quick analysis of target characteristics, training vs testing data, and other such data characterization tasks.
#
#
# GitHub: https://github.com/fbdesignpro/sweetviz

# %%
import sweetviz as sv
import pandas as pd
import yfinance as yf

# %%
amzn_df = yf.Ticker('AMZN').history(period='1d', start='2021-1-02', end='2021-12-12')
sv.analyze(amzn_df).show_notebook()
# Out:
#                                              |          | [  0%]   00:00 -> (? left)
#  <iframe width="100%" height="750" srcdoc="&lt;!doctype html&gt;
# &lt;html lang=&quot;en&quot;&gt;
# &lt;head&gt;
#     &lt;meta charset=&quot;UTF-8&quot;&gt;
#     &lt;link rel=&quot;icon&quot; href=&quot;data:image/x-icon;base64,...&quot; type=&quot;image/x-icon&quot; /&gt;
#         &lt;script&gt; /*! jQuery v3.7.1 | (c) OpenJS Foundation and other contributors | jquery.org/license */
# ...

# %%
amzn_df
# Out:
#                                  Open        High         Low       Close  \
# Date
# 2021-01-04 00:00:00-05:00  163.500000  163.600006  157.201004  159.331497
# 2021-01-05 00:00:00-05:00  158.300507  161.169006  158.253006  160.925507
# 2021-01-06 00:00:00-05:00  157.324005  159.875504  156.557999  156.919006
# 2021-01-07 00:00:00-05:00  157.850006  160.427002  157.750000  158.108002
# 2021-01-08 00:00:00-05:00  159.000000  159.531998  157.110001  159.134995
# ...                               ...         ...         ...         ...
# 2021-12-06 00:00:00-05:00  169.649994  173.695496  166.934494  171.368500
# 2021-12-07 00:00:00-05:00  174.600006  177.499496  173.334503  176.164505
# 2021-12-08 00:00:00-05:00  176.150497  177.179993  174.750504  176.158005
# 2021-12-09 00:00:00-05:00  175.750000  176.969498  174.139496  174.171005
# 2021-12-10 00:00:00-05:00  175.417007  175.927002  170.500000  172.212006
#
#                              Volume  Dividends  Stock Splits
# Date
# ...

# %%
googl_df = yf.Ticker('GOOGL').history(period='1d', start='2021-1-02', end='2021-12-12')

sv.compare(amzn_df, googl_df).show_notebook()
# Out:
#                                              |          | [  0%]   00:00 -> (? left)
#  <iframe width="100%" height="750" srcdoc="&lt;!doctype html&gt;
# &lt;html lang=&quot;en&quot;&gt;
# &lt;head&gt;
#     &lt;meta charset=&quot;UTF-8&quot;&gt;
#     &lt;link rel=&quot;icon&quot; href=&quot;data:image/x-icon;base64,...&quot; type=&quot;image/x-icon&quot; /&gt;
#         &lt;script&gt; /*! jQuery v3.7.1 | (c) OpenJS Foundation and other contributors | jquery.org/license */
# ...
