# %% [markdown]
# ## D-Tale
# D-Tale is an open-source Python library that’s used for data analysis and visualization. It’s a tool that’s designed to help you get a detailed EDA of your data. D-Tale also has a feature that allows you to export the code for every plot or analysis in the report.
#
#
# D-Tale was inspired by the awesome Python package, Pandas Profiling. Its goal is to bring the same type of analysis that Pandas Profiling provided, but in a more interactive and configurable manner. D-Tale also provides some of the awesome benefits that come with using React and Flask together (i.e. Flask can manage your JS dependencies, React can handle rendering on the front-end).
#
#
# GitHub: https://github.com/man-group/dtale

# %%
# Install dtale
# !pip install dtale
# Out:
# Collecting dtale
#   Obtaining dependency information for dtale from https://files.pythonhosted.org/packages/d9/5a/ccb7d9b990618364f7a4636325e8616ac69e7766f5c993272da15563bd38/dtale-3.16.1-py2.py3-none-any.whl.metadata
#   Downloading dtale-3.16.1-py2.py3-none-any.whl.metadata (16 kB)
# Collecting dash-colorscales (from dtale)
#   Using cached dash_colorscales-0.0.4-py3-none-any.whl
# Collecting dash-daq (from dtale)
#   Using cached dash_daq-0.5.0-py3-none-any.whl
# Collecting future>=0.14.0 (from dtale)
#   Obtaining dependency information for future>=0.14.0 from https://files.pythonhosted.org/packages/da/71/ae30dadffc90b9006d77af76b393cb9dfbfc9629f339fc1574a1c52e6806/future-1.0.0-py3-none-any.whl.metadata
#   Downloading future-1.0.0-py3-none-any.whl.metadata (4.0 kB)
# Collecting missingno (from dtale)
#   Obtaining dependency information for missingno from https://files.pythonhosted.org/packages/87/22/cd5cf999af21c2f97486622c551ac3d07361ced8125121e907f588ff5f24/missingno-0.5.2-py3-none-any.whl.metadata
#   Downloading missingno-0.5.2-py3-none-any.whl.metadata (639 bytes)
# Requirement already satisfied: pandas in ./venv/lib/python3.11/site-packages (from dtale) (2.2.3)
# Collecting squarify (from dtale)
#   Obtaining dependency information for squarify from https://files.pythonhosted.org/packages/b7/3c/eedbe9fb07cc20fd9a8423da14b03bc270d0570b3ba9174a4497156a2152/squarify-0.4.4-py3-none-any.whl.metadata
#   Downloading squarify-0.4.4-py3-none-any.whl.metadata (600 bytes)
# Collecting strsimpy (from dtale)
#   Obtaining dependency information for strsimpy from https://files.pythonhosted.org/packages/fc/90/bd55a4b18f4b75a76e32f444975d2c869d692eb23897d116d47122f88d1a/strsimpy-0.2.1-py3-none-any.whl.metadata
#   Downloading strsimpy-0.2.1-py3-none-any.whl.metadata (20 kB)
# Requirement already satisfied: six in ./venv/lib/python3.11/site-packages (from dtale) (1.17.0)
# Collecting xlrd (from dtale)
#   Obtaining dependency information for xlrd from https://files.pythonhosted.org/packages/a6/0c/c2a72d51fe56e08a08acc85d13013558a2d793028ae7385448a6ccdfae64/xlrd-2.0.1-py2.py3-none-any.whl.metadata
#   Downloading xlrd-2.0.1-py2.py3-none-any.whl.metadata (3.4 kB)
# Requirement already satisfied: beautifulsoup4!=4.13.0b2 in ./venv/lib/python3.11/site-packages (from dtale) (4.13.3)
# Requirement already satisfied: certifi in ./venv/lib/python3.11/site-packages (from dtale) (2025.1.31)
# Collecting dash-bootstrap-components (from dtale)
#   Obtaining dependency information for dash-bootstrap-components from https://files.pythonhosted.org/packages/c3/87/4db3b56e9a6813d413a0f20e053aa163d652babb629a8bf7b871af4a075f/dash_bootstrap_components-1.7.1-py3-none-any.whl.metadata
#   Downloading dash_bootstrap_components-1.7.1-py3-none-any.whl.metadata (17 kB)
# Collecting lz4 (from dtale)
#   Obtaining dependency information for lz4 from https://files.pythonhosted.org/packages/27/08/ab9008c869ad16f158255514e1870156cebf9c2bf0509aadfddeb5dc2183/lz4-4.4.3-cp311-cp311-macosx_11_0_arm64.whl.metadata
#   Downloading lz4-4.4.3-cp311-cp311-macosx_11_0_arm64.whl.metadata (3.8 kB)
# Requirement already satisfied: cycler in ./venv/lib/python3.11/site-packages (from dtale) (0.12.1)
# Collecting dash (from dtale)
#   Obtaining dependency information for dash from https://files.pythonhosted.org/packages/72/ef/d46131f4817f18b329e4fb7c53ba1d31774239d91266a74bccdc932708cc/dash-2.18.2-py3-none-any.whl.metadata
#   Downloading dash-2.18.2-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: seaborn in ./venv/lib/python3.11/site-packages (from dtale) (0.13.2)
# Collecting werkzeug (from dtale)
#   Obtaining dependency information for werkzeug from https://files.pythonhosted.org/packages/52/24/ab44c871b0f07f491e5d2ad12c9bd7358e527510618cb1b803a88e986db1/werkzeug-3.1.3-py3-none-any.whl.metadata
#   Downloading werkzeug-3.1.3-py3-none-any.whl.metadata (3.7 kB)
# Collecting Flask-Compress (from dtale)
#   Obtaining dependency information for Flask-Compress from https://files.pythonhosted.org/packages/f7/54/ff08f947d07c0a8a5d8f1c8e57b142c97748ca912b259db6467ab35983cd/Flask_Compress-1.17-py3-none-any.whl.metadata
#   Downloading Flask_Compress-1.17-py3-none-any.whl.metadata (8.8 kB)
# Collecting scikit-learn (from dtale)
#   Obtaining dependency information for scikit-learn from https://files.pythonhosted.org/packages/25/92/ee1d7a00bb6b8c55755d4984fd82608603a3cc59959245068ce32e7fb808/scikit_learn-1.6.1-cp311-cp311-macosx_12_0_arm64.whl.metadata
#   Downloading scikit_learn-1.6.1-cp311-cp311-macosx_12_0_arm64.whl.metadata (31 kB)
# Requirement already satisfied: statsmodels in ./venv/lib/python3.11/site-packages (from dtale) (0.14.4)
# Requirement already satisfied: networkx in ./venv/lib/python3.11/site-packages (from dtale) (3.4.2)
# Requirement already satisfied: numpy in ./venv/lib/python3.11/site-packages (from dtale) (2.1.3)
# Collecting openpyxl!=3.2.0b1 (from dtale)
#   Obtaining dependency information for openpyxl!=3.2.0b1 from https://files.pythonhosted.org/packages/c0/da/977ded879c29cbd04de313843e76868e6e13408a94ed6b987245dc7c8506/openpyxl-3.1.5-py2.py3-none-any.whl.metadata
#   Downloading openpyxl-3.1.5-py2.py3-none-any.whl.metadata (2.5 kB)
# Collecting xarray (from dtale)
#   Obtaining dependency information for xarray from https://files.pythonhosted.org/packages/05/79/4e19100342fe13d69fd6e77b343e2269924fec681258e2ea21b55576aad2/xarray-2025.1.2-py3-none-any.whl.metadata
#   Downloading xarray-2025.1.2-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: scipy!=1.12.0rc1,!=1.14.0,!=1.14.0rc1,!=1.14.0rc2 in ./venv/lib/python3.11/site-packages (from dtale) (1.15.1)
# Collecting et-xmlfile (from dtale)
#   Obtaining dependency information for et-xmlfile from https://files.pythonhosted.org/packages/c1/8b/5fe2cc11fee489817272089c4203e679c63b570a5aaeb18d852ae3cbba6a/et_xmlfile-2.0.0-py3-none-any.whl.metadata
#   Downloading et_xmlfile-2.0.0-py3-none-any.whl.metadata (2.7 kB)
# Collecting plotly (from dtale)
#   Obtaining dependency information for plotly from https://files.pythonhosted.org/packages/0e/77/a946f38b57fb88e736c71fbdd737a1aebd27b532bda0779c137f357cf5fc/plotly-6.0.0-py3-none-any.whl.metadata
#   Downloading plotly-6.0.0-py3-none-any.whl.metadata (5.6 kB)
# Collecting Flask (from dtale)
#   Obtaining dependency information for Flask from https://files.pythonhosted.org/packages/af/47/93213ee66ef8fae3b93b3e29206f6b251e65c97bd91d8e1c5596ef15af0a/flask-3.1.0-py3-none-any.whl.metadata
#   Downloading flask-3.1.0-py3-none-any.whl.metadata (2.7 kB)
# Collecting itsdangerous (from dtale)
#   Obtaining dependency information for itsdangerous from https://files.pythonhosted.org/packages/04/96/92447566d16df59b2a776c0fb82dbc4d9e07cd95062562af01e408583fc4/itsdangerous-2.2.0-py3-none-any.whl.metadata
#   Downloading itsdangerous-2.2.0-py3-none-any.whl.metadata (1.9 kB)
# Requirement already satisfied: requests in ./venv/lib/python3.11/site-packages (from dtale) (2.32.3)
# Collecting kaleido (from dtale)
#   Obtaining dependency information for kaleido from https://files.pythonhosted.org/packages/45/8e/4297556be5a07b713bb42dde0f748354de9a6918dee251c0e6bdcda341e7/kaleido-0.2.1-py2.py3-none-macosx_11_0_arm64.whl.metadata
#   Downloading kaleido-0.2.1-py2.py3-none-macosx_11_0_arm64.whl.metadata (15 kB)
# Requirement already satisfied: matplotlib in ./venv/lib/python3.11/site-packages (from dtale) (3.10.0)
# Requirement already satisfied: soupsieve>1.2 in ./venv/lib/python3.11/site-packages (from beautifulsoup4!=4.13.0b2->dtale) (2.6)
# Requirement already satisfied: typing-extensions>=4.0.0 in ./venv/lib/python3.11/site-packages (from beautifulsoup4!=4.13.0b2->dtale) (4.12.2)
# Collecting Flask (from dtale)
#   Obtaining dependency information for Flask from https://files.pythonhosted.org/packages/61/80/ffe1da13ad9300f87c93af113edd0638c75138c42a0994becfacac078c06/flask-3.0.3-py3-none-any.whl.metadata
#   Downloading flask-3.0.3-py3-none-any.whl.metadata (3.2 kB)
# Collecting werkzeug (from dtale)
#   Obtaining dependency information for werkzeug from https://files.pythonhosted.org/packages/6c/69/05837f91dfe42109203ffa3e488214ff86a6d68b2ed6c167da6cdc42349b/werkzeug-3.0.6-py3-none-any.whl.metadata
#   Downloading werkzeug-3.0.6-py3-none-any.whl.metadata (3.7 kB)
# Collecting dash-html-components==2.0.0 (from dash->dtale)
#   Obtaining dependency information for dash-html-components==2.0.0 from https://files.pythonhosted.org/packages/75/65/1b16b853844ef59b2742a7de74a598f376ac0ab581f0dcc34db294e5c90e/dash_html_components-2.0.0-py3-none-any.whl.metadata
#   Downloading dash_html_components-2.0.0-py3-none-any.whl.metadata (3.8 kB)
# Collecting dash-core-components==2.0.0 (from dash->dtale)
#   Obtaining dependency information for dash-core-components==2.0.0 from https://files.pythonhosted.org/packages/00/9e/a29f726e84e531a36d56cff187e61d8c96d2cc253c5bcef9a7695acb7e6a/dash_core_components-2.0.0-py3-none-any.whl.metadata
#   Downloading dash_core_components-2.0.0-py3-none-any.whl.metadata (2.9 kB)
# Collecting dash-table==5.0.0 (from dash->dtale)
#   Obtaining dependency information for dash-table==5.0.0 from https://files.pythonhosted.org/packages/da/ce/43f77dc8e7bbad02a9f88d07bf794eaf68359df756a28bb9f2f78e255bb1/dash_table-5.0.0-py3-none-any.whl.metadata
#   Downloading dash_table-5.0.0-py3-none-any.whl.metadata (2.4 kB)
# Collecting importlib-metadata (from dash->dtale)
#   Obtaining dependency information for importlib-metadata from https://files.pythonhosted.org/packages/79/9d/0fb148dc4d6fa4a7dd1d8378168d9b4cd8d4560a6fbf6f0121c5fc34eb68/importlib_metadata-8.6.1-py3-none-any.whl.metadata
#   Downloading importlib_metadata-8.6.1-py3-none-any.whl.metadata (4.7 kB)
# Collecting retrying (from dash->dtale)
#   Obtaining dependency information for retrying from https://files.pythonhosted.org/packages/8f/04/9e36f28be4c0532c0e9207ff9dc01fb13a2b0eb036476a213b0000837d0e/retrying-1.3.4-py3-none-any.whl.metadata
#   Downloading retrying-1.3.4-py3-none-any.whl.metadata (6.9 kB)
# Requirement already satisfied: nest-asyncio in ./venv/lib/python3.11/site-packages (from dash->dtale) (1.6.0)
# Requirement already satisfied: setuptools in ./venv/lib/python3.11/site-packages (from dash->dtale) (68.2.0)
# Requirement already satisfied: Jinja2>=3.1.2 in ./venv/lib/python3.11/site-packages (from Flask->dtale) (3.1.5)
# Collecting click>=8.1.3 (from Flask->dtale)
#   Obtaining dependency information for click>=8.1.3 from https://files.pythonhosted.org/packages/7e/d4/7ebdbd03970677812aac39c869717059dbb71a4cfc033ca6e5221787892c/click-8.1.8-py3-none-any.whl.metadata
#   Using cached click-8.1.8-py3-none-any.whl.metadata (2.3 kB)
# Collecting blinker>=1.6.2 (from Flask->dtale)
#   Obtaining dependency information for blinker>=1.6.2 from https://files.pythonhosted.org/packages/10/cb/f2ad4230dc2eb1a74edf38f1a38b9b52277f75bef262d8908e60d957e13c/blinker-1.9.0-py3-none-any.whl.metadata
#   Downloading blinker-1.9.0-py3-none-any.whl.metadata (1.6 kB)
# Collecting narwhals>=1.15.1 (from plotly->dtale)
#   Obtaining dependency information for narwhals>=1.15.1 from https://files.pythonhosted.org/packages/15/fc/420680ad8b0cf81372eee7a213a7b7173ec5a628f0d5b2426047fe55c3b3/narwhals-1.26.0-py3-none-any.whl.metadata
#   Downloading narwhals-1.26.0-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: packaging in ./venv/lib/python3.11/site-packages (from plotly->dtale) (24.2)
# Requirement already satisfied: MarkupSafe>=2.1.1 in ./venv/lib/python3.11/site-packages (from werkzeug->dtale) (3.0.2)
# Collecting brotli (from Flask-Compress->dtale)
#   Obtaining dependency information for brotli from https://files.pythonhosted.org/packages/96/12/ad41e7fadd5db55459c4c401842b47f7fee51068f86dd2894dd0dcfc2d2a/Brotli-1.1.0-cp311-cp311-macosx_10_9_universal2.whl.metadata
#   Downloading Brotli-1.1.0-cp311-cp311-macosx_10_9_universal2.whl.metadata (5.5 kB)
# Collecting zstandard (from Flask-Compress->dtale)
#   Obtaining dependency information for zstandard from https://files.pythonhosted.org/packages/e8/46/66d5b55f4d737dd6ab75851b224abf0afe5774976fe511a54d2eb9063a41/zstandard-0.23.0-cp311-cp311-macosx_11_0_arm64.whl.metadata
#   Downloading zstandard-0.23.0-cp311-cp311-macosx_11_0_arm64.whl.metadata (3.0 kB)
# Requirement already satisfied: contourpy>=1.0.1 in ./venv/lib/python3.11/site-packages (from matplotlib->dtale) (1.3.1)
# Requirement already satisfied: fonttools>=4.22.0 in ./venv/lib/python3.11/site-packages (from matplotlib->dtale) (4.56.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in ./venv/lib/python3.11/site-packages (from matplotlib->dtale) (1.4.8)
# Requirement already satisfied: pillow>=8 in ./venv/lib/python3.11/site-packages (from matplotlib->dtale) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in ./venv/lib/python3.11/site-packages (from matplotlib->dtale) (3.2.1)
# Requirement already satisfied: python-dateutil>=2.7 in ./venv/lib/python3.11/site-packages (from matplotlib->dtale) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in ./venv/lib/python3.11/site-packages (from pandas->dtale) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in ./venv/lib/python3.11/site-packages (from pandas->dtale) (2025.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in ./venv/lib/python3.11/site-packages (from requests->dtale) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in ./venv/lib/python3.11/site-packages (from requests->dtale) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in ./venv/lib/python3.11/site-packages (from requests->dtale) (2.3.0)
# Requirement already satisfied: joblib>=1.2.0 in ./venv/lib/python3.11/site-packages (from scikit-learn->dtale) (1.4.2)
# Collecting threadpoolctl>=3.1.0 (from scikit-learn->dtale)
#   Obtaining dependency information for threadpoolctl>=3.1.0 from https://files.pythonhosted.org/packages/4b/2c/ffbf7a134b9ab11a67b0cf0726453cedd9c5043a4fe7a35d1cefa9a1bcfb/threadpoolctl-3.5.0-py3-none-any.whl.metadata
#   Downloading threadpoolctl-3.5.0-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: patsy>=0.5.6 in ./venv/lib/python3.11/site-packages (from statsmodels->dtale) (1.0.1)
# Collecting zipp>=3.20 (from importlib-metadata->dash->dtale)
#   Obtaining dependency information for zipp>=3.20 from https://files.pythonhosted.org/packages/b7/1a/7e4798e9339adc931158c9d69ecc34f5e6791489d469f5e50ec15e35f458/zipp-3.21.0-py3-none-any.whl.metadata
#   Using cached zipp-3.21.0-py3-none-any.whl.metadata (3.7 kB)
# Downloading dtale-3.16.1-py2.py3-none-any.whl (14.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.7/14.7 MB 6.1 MB/s eta 0:00:0000:0100:01
# Downloading future-1.0.0-py3-none-any.whl (491 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 491.3/491.3 kB 30.8 MB/s eta 0:00:00
# Downloading openpyxl-3.1.5-py2.py3-none-any.whl (250 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 250.9/250.9 kB 11.5 MB/s eta 0:00:00
# Downloading dash-2.18.2-py3-none-any.whl (7.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 27.5 MB/s eta 0:00:00a 0:00:01
# Downloading dash_core_components-2.0.0-py3-none-any.whl (3.8 kB)
# Downloading dash_html_components-2.0.0-py3-none-any.whl (4.1 kB)
# Downloading dash_table-5.0.0-py3-none-any.whl (3.9 kB)
# Downloading flask-3.0.3-py3-none-any.whl (101 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 101.7/101.7 kB 13.9 MB/s eta 0:00:00
# Downloading itsdangerous-2.2.0-py3-none-any.whl (16 kB)
# Downloading plotly-6.0.0-py3-none-any.whl (14.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.8/14.8 MB 31.6 MB/s eta 0:00:0000:0100:01
# Downloading werkzeug-3.0.6-py3-none-any.whl (227 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 228.0/228.0 kB 11.8 MB/s eta 0:00:00
# Downloading dash_bootstrap_components-1.7.1-py3-none-any.whl (229 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 229.3/229.3 kB 14.8 MB/s eta 0:00:00
# Downloading et_xmlfile-2.0.0-py3-none-any.whl (18 kB)
# Downloading Flask_Compress-1.17-py3-none-any.whl (8.7 kB)
# Downloading kaleido-0.2.1-py2.py3-none-macosx_11_0_arm64.whl (85.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 85.8/85.8 MB 14.4 MB/s eta 0:00:0000:0100:01
# Downloading lz4-4.4.3-cp311-cp311-macosx_11_0_arm64.whl (189 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 189.5/189.5 kB 10.2 MB/s eta 0:00:00
# Downloading missingno-0.5.2-py3-none-any.whl (8.7 kB)
# Downloading scikit_learn-1.6.1-cp311-cp311-macosx_12_0_arm64.whl (11.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.1/11.1 MB 43.9 MB/s eta 0:00:00a 0:00:01
# Downloading squarify-0.4.4-py3-none-any.whl (4.1 kB)
# Downloading strsimpy-0.2.1-py3-none-any.whl (45 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.9/45.9 kB 7.4 MB/s eta 0:00:00
# Downloading xarray-2025.1.2-py3-none-any.whl (1.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 34.5 MB/s eta 0:00:0000:01
# Downloading xlrd-2.0.1-py2.py3-none-any.whl (96 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 96.5/96.5 kB 12.4 MB/s eta 0:00:00
# Downloading blinker-1.9.0-py3-none-any.whl (8.5 kB)
# Using cached click-8.1.8-py3-none-any.whl (98 kB)
# Downloading narwhals-1.26.0-py3-none-any.whl (306 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 306.6/306.6 kB 12.3 MB/s eta 0:00:00
# Downloading threadpoolctl-3.5.0-py3-none-any.whl (18 kB)
# Downloading Brotli-1.1.0-cp311-cp311-macosx_10_9_universal2.whl (873 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 873.1/873.1 kB 44.9 MB/s eta 0:00:00a 0:00:01
# Downloading importlib_metadata-8.6.1-py3-none-any.whl (26 kB)
# Downloading retrying-1.3.4-py3-none-any.whl (11 kB)
# Downloading zstandard-0.23.0-cp311-cp311-macosx_11_0_arm64.whl (633 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 633.7/633.7 kB 34.3 MB/s eta 0:00:00
# Using cached zipp-3.21.0-py3-none-any.whl (9.6 kB)
# Installing collected packages: strsimpy, squarify, kaleido, dash-table, dash-html-components, dash-core-components, dash-colorscales, brotli, zstandard, zipp, xlrd, werkzeug, threadpoolctl, retrying, narwhals, lz4, itsdangerous, future, et-xmlfile, click, blinker, scikit-learn, plotly, openpyxl, importlib-metadata, Flask, xarray, Flask-Compress, dash, missingno, dash-daq, dash-bootstrap-components, dtale
# Successfully installed Flask-3.0.3 Flask-Compress-1.17 blinker-1.9.0 brotli-1.1.0 click-8.1.8 dash-2.18.2 dash-bootstrap-components-1.7.1 dash-colorscales-0.0.4 dash-core-components-2.0.0 dash-daq-0.5.0 dash-html-components-2.0.0 dash-table-5.0.0 dtale-3.16.1 et-xmlfile-2.0.0 future-1.0.0 importlib-metadata-8.6.1 itsdangerous-2.2.0 kaleido-0.2.1 lz4-4.4.3 missingno-0.5.2 narwhals-1.26.0 openpyxl-3.1.5 plotly-6.0.0 retrying-1.3.4 scikit-learn-1.6.1 squarify-0.4.4 strsimpy-0.2.1 threadpoolctl-3.5.0 werkzeug-3.0.6 xarray-2025.1.2 xlrd-2.0.1 zipp-3.21.0 zstandard-0.23.0
#
# [notice] A new release of pip is available: 23.2.1 -> 25.0.1
# [notice] To update, run: pip install --upgrade pip

# %%
import pandas as pd
import dtale

df = pd.read_csv('bankdata.csv')

dtale.show(df)
# Out:
#         <iframe
#             width="100%"
#             height="475"
#             src="http://Codings-MacBook-Pro.local:40000/dtale/iframe/1"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
